# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from urllib.parse import quote, unquote
from bs4 import BeautifulSoup
from collections import Counter
import seaborn as sns
from statistics import mean
from matplotlib.colors import LogNorm
import networkx as nx

# %%
# Load list of dataframes containing links

path_list = []
for i in range(9, 23):
    path_list.append('Wiki_Revs/links' + str(i) + '.tsv')


year_list = []
for i in range(2009, 2023):
    year_list.append(i)

links_dict = {}
for path, year in zip(path_list, year_list):
    links_dict[year] = (pd.read_csv(path, comment='#', delimiter='\t'))

for df in links_dict.values():
    df.drop_duplicates(inplace=True)
    df.reset_index(drop=True, inplace=True)

# %%
links_dict[2009].head()
# Out:
#                          linkSource      linkTarget
# 0  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in            Bede
# 1  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in         Columba
# 2  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  D%C3%A1l_Riata
# 3  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in   Great_Britain
# 4  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in         Ireland

# %%
def create_graph_from_links(links):
    graph = nx.DiGraph()
    for l, r in links.iterrows():
        graph.add_weighted_edges_from([(r['linkSource'], r['linkTarget'], 1)])
    return graph

def calculate_page_rank(graph):
    graph_page_rank = nx.pagerank(graph)
    graph_page_rank_rank = {k:i+1 for i, (k, v) in enumerate(sorted(graph_page_rank.items(), key=lambda item: item[1], reverse=True))}
    graph_page_rank = {k:graph_page_rank[k] for k in graph_page_rank}
    return graph_page_rank, graph_page_rank_rank

# %%
graphs = {}
for year, links in links_dict.items():
    graphs[year] = create_graph_from_links(links)

page_ranks = {}
page_rank_ranks = {}
for year, graph in graphs.items():
    page_ranks[year], page_rank_ranks[year] = calculate_page_rank(graph)

# %%
def get_degrees(graph):
    in_degrees = graph.in_degree()
    out_degrees = graph.out_degree()
    return dict(in_degrees), dict(out_degrees)

outlinks = {}
inlinks = {}
for year, graph in graphs.items():
    inlinks[year], outlinks[year] = get_degrees(graph)

# %%
def shifters(year, prr, rev=True):
    cur_year = year
    next_year = year + 1
    diff_tuple = ((art, (prr[cur_year][art] - prr[next_year][art])) for art in prr[cur_year].keys() if art in prr[next_year].keys())
    diff_tupsort = sorted(diff_tuple, key=lambda x: x[1], reverse=rev)
    return diff_tupsort

# %%
res = shifters(2020, inlinks)
print(res[:10])
# Out:
# [('Bah%C3%A1%27%C3%AD_Faith', 62), ('Industry', 50), ('Kiev', 42), ('Polish-Lithuanian_Commonwealth', 16), ('Earth', 12), ('China', 11), ('European_Parliament', 11), ('Judaism', 11), ('Piano', 10), ('Accra', 10)]

# %%
# The main categories that we are interested in (we have chosen these ourselves)
wiki_2009_categories = pd.read_csv('./wikispeedia_paths-and-graph/categories.tsv', delim_whitespace=True, names=['article', 'category'], comment='#')

# When articles have more than one main category, we choose to sample one.
# This is perhaps not an optimal method, but it is currently the best we can think of.
wiki_2009_categories = wiki_2009_categories.groupby('article').sample(1)
wiki_2009_categories['category'] = wiki_2009_categories['category'].str.extract(r'subject\.([a-zA-Z]*)')
wiki_2009_categories = wiki_2009_categories.set_index('article')
article_cat = wiki_2009_categories.to_dict()['category']

# %%
shifts2 = []
for year in range(2010, 2022):
    ins = shifters(year, inlinks)[:5]
    outs = shifters(year, outlinks)[:5]
    for i in range(5):
        shifts2.append([year, unquote(ins[i][0]), ins[i][1], unquote(outs[i][0]), outs[i][1]])
shifts2df = pd.DataFrame(shifts2, columns=['year', 'Inlink Page', 'Increase inlinks', 'Outlink Page', 'Increase outlinks'])
shifts2df
# Out:
#     year                     Inlink Page  Increase inlinks  \
# 0   2010                   United_States               106
# 1   2010                          Europe                86
# 2   2010                         England                78
# 3   2010                    World_War_II                74
# 4   2010                          France                66
# 5   2011                   United_States               111
# 6   2011                         England                89
# 7   2011                          France                88
# 8   2011                          Europe                84
# 9   2011                  United_Kingdom                68
# 10  2012                   United_States                68
# 11  2012                  United_Kingdom                50
# 12  2012      People's_Republic_of_China                49
# 13  2012                          Europe                48
# 14  2012                          London                47
# 15  2013           Binomial_nomenclature                76
# 16  2013       Scientific_classification                74
# 17  2013                Carolus_Linnaeus                69
# 18  2013                          Animal                66
# 19  2013                        Chordate                64
# 20  2014                  Persian_Empire                37
# 21  2014                   United_States                35
# 22  2014                          Market                24
# 23  2014                          France                23
# 24  2014      People's_Republic_of_China                19
# 25  2015                Carolus_Linnaeus                57
# 26  2015                         England                19
# 27  2015                   Côte_d'Ivoire                19
# 28  2015                           Japan                15
# 29  2015      People's_Republic_of_China                14
# 30  2016                   United_States                53
# 31  2016                  United_Kingdom                37
# 32  2016                          France                31
# 33  2016                          Canada                28
# 34  2016                         Ireland                26
# 35  2017               Liberal_Democrats                35
# 36  2017                            Wine                20
# 37  2017                     Agriculture                18
# 38  2017                William_and_Mary                18
# 39  2017                      Television                17
# 40  2018                        Portugal                16
# 41  2018                      Wikisource                16
# 42  2018                          Canada                14
# 43  2018                          Russia                13
# 44  2018                     Open_source                13
# 45  2019           Republic_of_Macedonia                26
# 46  2019                   United_States                25
# 47  2019                       Australia                22
# 48  2019                          France                21
# 49  2019                      Chimpanzee                21
# 50  2020                    Bahá'í_Faith                62
# 51  2020                        Industry                50
# 52  2020                            Kiev                42
# 53  2020  Polish-Lithuanian_Commonwealth                16
# 54  2020                           Earth                12
# 55  2021         Encyclopædia_Britannica               135
# 56  2021                   United_States                42
# 57  2021                           China                37
# 58  2021                  United_Kingdom                30
# 59  2021                           Japan                30
#
#                                      Outlink Page  Increase outlinks
# 0                                       Nicaragua                152
# 1                                           Ghana                150
# 2                                British_monarchy                112
# 3                                      Costa_Rica                 95
# 4                                        Istanbul                 87
# 5                    Driving_on_the_left_or_right                254
# 6                                           India                136
# 7                         Los_Angeles,_California                112
# 8                                   United_States                 92
# 9                                          Canada                 91
# 10                              Pope_John_Paul_II                131
# 11                                       Universe                109
# 12                                    Visual_arts                101
# 13                                       Shanghai                 87
# 14                                    The_X-Files                 79
# 15                                           Time                119
# 16                                         Cyprus                 90
# 17                                        Lebanon                 82
# 18                                        Romania                 78
# 19                                 Miami,_Florida                 76
# 20                               History_of_Earth                150
# 21                                       Malaysia                147
# 22                                     Gadolinium                121
# 23                                           City                102
# 24                                British_English                 78
# 25                                         Russia                228
# 26                                    Global_city                218
# 27                       List_of_elements_by_name                120
# 28                            Trinidad_and_Tobago                 85
# 29                          Military_dictatorship                 80
# 30                                      Nutrition                160
# 31                                        Moldova                127
# 32                                     Montenegro                108
# 33                                 Atlantic_Ocean                 96
# 34                                      Community                 95
# 35                                            Sea                209
# 36                         Southern_United_States                100
# 37                                       Helsinki                 93
# 38                        Democratic_Action_Party                 86
# 39                 Politics_of_the_United_Kingdom                 76
# 40                                         France                356
# 41                                    Global_city                197
# 42                                         Berlin                162
# 43                                       Fluorine                125
# 44                                      Hong_Kong                 92
# 45                                 Modern_history                206
# 46                                       Interpol                196
# 47                                         Mosque                109
# 48                                         London                 96
# 49  List_of_Prime_Ministers_of_the_United_Kingdom                 76
# 50                                        Baghdad                132
# 51                                        Chicago                107
# 52                                         Moscow                 56
# 53                                 Mount_Pinatubo                 53
# 54                                      Wikipedia                 47
# 55                                  Guinea-Bissau                165
# 56                       List_of_rivers_by_length                155
# 57                                         Turkey                129
# 58                                      Time_zone                129
# 59                                          Plant                117

# %%
shifts = []
freq_cat = dict()
freq_cat_down = dict()
for year in range(2010, 2022):
    up_5 = shifters(year, page_rank_ranks, True)[:5]
    down_5 = shifters(year, page_rank_ranks, False)[:5]
    for i in range(5):
        shifts.append([year, unquote(up_5[i][0]), up_5[i][1], unquote(down_5[i][0]), down_5[i][1]])
        cat = article_cat[up_5[i][0]]
        if down_5[i][0] in article_cat:
            catd = article_cat[down_5[i][0]]
            if catd in freq_cat_down:
                freq_cat_down[catd] += 1
            else:
                freq_cat_down[catd] = 1
        if cat in freq_cat:
            freq_cat[cat] += 1
        else:
            freq_cat[cat] = 1
shiftsdf = pd.DataFrame(shifts, columns=['year', 'up_1', 'up_1_val', 'down_1', 'down_1_val'])
shiftsdf
# print(shifters(2021, page_rank_ranks, False)[:5])
# Out:
#     year                                           up_1  up_1_val  \
# 0   2010                             Spring_Heeled_Jack      3246
# 1   2010                                    Whitethroat      3199
# 2   2010                          Storm_of_October_1804      3160
# 3   2010                       Rebecca_Helferich_Clarke      3136
# 4   2010                                        Pochard      3134
# 5   2011                                Project_MKULTRA      3237
# 6   2011                           Short-beaked_Echidna      3179
# 7   2011                                    Shrimp_farm      3093
# 8   2011                               Scent_of_a_Woman      3092
# 9   2011                                  Roan_Antelope      3086
# 10  2012                           Weyauwega_derailment      3117
# 11  2012                              White's_Tree_Frog      3116
# 12  2012                                Trabancos_River      3094
# 13  2012                                        Arugula      3069
# 14  2012                                   Reed_Bunting      3069
# 15  2013                                    Pied_Avocet      3129
# 16  2013                           Rose-ringed_Parakeet      3057
# 17  2013                    Southern_Rockhopper_Penguin      3042
# 18  2013                              Umbrella_Cockatoo      3035
# 19  2013                       Swedish_allotment_system      3013
# 20  2014                      Diffuse_interstellar_band      4016
# 21  2014                         Ursuline_Convent_Riots      2999
# 22  2014                         The_Children's_Machine      2978
# 23  2014                           Order_of_St._Patrick      2970
# 24  2014                         Cathedral_of_Magdeburg      2965
# 25  2015                                  Caloris_Basin      2993
# 26  2015                          To_Kill_a_Mockingbird      2983
# 27  2015                         €2_commemorative_coins      2972
# 28  2015                                      Ununtrium      2971
# 29  2015                                   Triggerplant      2966
# 30  2016                             Battle_of_Normandy      2974
# 31  2016             Collapse_of_the_World_Trade_Center      2966
# 32  2016             Automatic_number_plate_recognition      2947
# 33  2016                                     Boston_RFC      2940
# 34  2016                              Opuntia_imbricata      2939
# 35  2017                          Swiss_Federal_Council      3040
# 36  2017                      Saint-Pierre_and_Miquelon      2966
# 37  2017                  List_of_world's_largest_lakes      2937
# 38  2017                  List_of_animal_welfare_groups      2929
# 39  2017                    Labor_Day_Hurricane_of_1935      2905
# 40  2018                            Aberration_of_light      3015
# 41  2018                                   Canada_Goose      2984
# 42  2018                              Abhidhamma_Pitaka      2963
# 43  2018                                Tay_Rail_Bridge      2955
# 44  2018                                Chepstow_Bridge      2941
# 45  2019                            History_of_Burnside      2979
# 46  2019                             Sears_Catalog_Home      2974
# 47  2019  List_of_Prime_Ministers_of_the_United_Kingdom      2963
# 48  2019                     Trade_and_usage_of_saffron      2916
# 49  2019                                      Karl_Benz      2838
# 50  2020     Effect_of_Hurricane_Katrina_on_New_Orleans      2985
# 51  2020                       Sardar_Vallabhbhai_Patel      2968
# 52  2020                                       Shelduck      2952
# 53  2020                                   Trinity_test      2950
# 54  2020                    Allegory_in_the_Middle_Ages      2912
# 55  2021                              William_Gladstone      2978
# 56  2021          List_of_monarchs_in_the_British_Isles      2941
# 57  2021                           FM_Consolidated_line      2939
# 58  2021                             Davy_Jones'_Locker      2920
# 59  2021                Gas_turbine-electric_locomotive      2920
#
#                                      down_1  down_1_val
# 0                              Belton_House       -2966
# 1                                   Nigella       -2832
# 2                                  Donation       -2590
# 3                              Felice_Beato       -2509
# 4                                    Wigeon       -2496
# 5                                  Conflict       -2819
# 6                                Kookaburra       -2396
# 7                                 Gardening       -2293
# 8                                   Menthol       -2263
# 9                                      Sumo       -2140
# 10                       History_of_Arizona       -3627
# 11                  History_of_South_Africa       -2472
# 12                               Oppression       -2450
# 13                                  Spyware       -2373
# 14                                    Stock       -2100
# 15  Canadian_Charter_of_Rights_and_Freedoms       -2748
# 16                                   Airbus       -2417
# 17                            Côte_d'Ivoire       -1525
# 18                        Battle_of_Britain       -1197
# 19                Scientific_classification       -1196
# 20                                   Market       -2945
# 21                                 Quantity       -2584
# 22                       Restoration_comedy       -2567
# 23                           Soil_structure       -2300
# 24                           The_Waste_Land       -2215
# 25                                Community       -2631
# 26                              Lake_Baikal       -2518
# 27                           Great_Red_Spot       -2497
# 28                             Moon_landing       -2432
# 29                                     Dove       -2295
# 30                                  Rhubarb       -2776
# 31                                   Wrench       -2710
# 32                    To_Kill_a_Mockingbird       -2593
# 33                                Asparagus       -2565
# 34                                    Brush       -2306
# 35                         William_and_Mary       -3426
# 36                                      Toy       -3080
# 37       Collapse_of_the_World_Trade_Center       -2722
# 38                                 Aardvark       -2645
# 39                                 Angelica       -2605
# 40                     History_of_Singapore       -2907
# 41                           Roman_Vishniac       -2784
# 42                           Brothers_Grimm       -2455
# 43                         Canadian_English       -2376
# 44                                     Race       -2371
# 45               Jordanhill_railway_station       -2746
# 46                                 Longship       -2642
# 47                                   Eskimo       -2606
# 48                                  Leisure       -2454
# 49                                  Ukulele       -2436
# 50                                  Nephron       -2733
# 51                            Soil_moisture       -2596
# 52                               Vacutainer       -2487
# 53                                 Industry       -2446
# 54                                     Hawk       -2357
# 55                       Battle_of_Hastings       -2406
# 56                                    Helen       -1962
# 57                                     Kiev       -1786
# 58                             20th_century       -1211
# 59                             19th_century       -1020

# %%
print(freq_cat)
print(freq_cat_down)
# Out:
# {'Religion': 4, 'Science': 20, 'Geography': 6, 'People': 4, 'History': 12, 'Everyday': 3, 'IT': 1, 'Design': 6, 'Language': 1, 'Business': 1, 'Citizenship': 2}
# {'Design': 5, 'Science': 13, 'People': 5, 'Citizenship': 5, 'Everyday': 6, 'History': 8, 'IT': 1, 'Business': 3, 'Geography': 6, 'Mathematics': 1, 'Language': 4, 'Art': 1, 'Music': 1}

# %%
print(article_cat['Defaka'])
# Out:
# Geography

# %%
prr = page_rank_ranks
cur_year = 2020
next_year = 2021
diff_tuple = ([art, (prr[cur_year][art] - prr[next_year][art])] for art in prr[cur_year].keys() if art in prr[next_year].keys())
diff_tupsort = sorted(diff_tuple, key=lambda x: x[1], reverse=True)
diff_tupsort = [(unquote(x[0]), x[1]) for x in diff_tupsort]
print(diff_tupsort[:20])
# Out:
# [('Effect_of_Hurricane_Katrina_on_New_Orleans', 2985), ('Sardar_Vallabhbhai_Patel', 2968), ('Shelduck', 2952), ('Trinity_test', 2950), ('Allegory_in_the_Middle_Ages', 2912), ('David_Heymann', 2909), ('London_sewerage_system', 2896), ('Kakapo', 2791), ('Sputnik_program', 2756), ('Saint_Lawrence_Seaway', 2692), ('National_parks_of_England_and_Wales', 2553), ('First_Transcontinental_Railroad', 2398), ('Margin_of_error', 2349), ('RER', 2234), ('Battle_of_Hastings', 2195), ('Persian_Empire', 2174), ('Eliminative_materialism', 2056), ('Boa', 1989), ('Newmarket', 1880), ('Sea_level_rise', 979)]

# %%
inl = inlinks
cur_year = 2010
next_year = 2022
diff_tuple = ([art, (inl[cur_year][art] - inl[next_year][art])] for art in inl[cur_year].keys() if art in inl[next_year].keys())
diff_tupsort = sorted(diff_tuple, key=lambda x: x[1], reverse=True)
diff_tupsort = [(unquote(x[0]), x[1]) for x in diff_tupsort]
print(diff_tupsort[:5])
# Out:
# [('United_States', 513), ('Europe', 358), ('United_Kingdom', 303), ('France', 291), ('England', 271)]
